# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("/Users/jordanburke/RNA-is-awesome/SP_analysis")
import SPTools

# %%
cd PEAKPICKING/
# Out:
# /Users/jordanburke/RNA-is-awesome/SP_ANALYSIS/PEAKPICKING

# %%
SPTools.peaks_by_gene("/Users/jordanburke/RNA-is-awesome/GENOMES/CNA3_FINAL_CALLGENES_1_gobs.gff3", "/Users/jordanburke/Documents/JEB/HTSeq/JEB002/150904BAMFILES/CM764-A_5p.bedGraph", gene_list=["CNAG_05698T0", "CNAG_06699T0", "CNAG_00483T0"])
# Out:
# 3
# CNAG_00483T0
# CNAG_05698T0
# CNAG_06699T0
# Totals
# 22 out of 27 5'-splice sites found
# 19 out of 27 3'-splice sites found
# 69 new peaks

# %%
SPTools.find_new_peak_sequence("/Users/jordanburke/RNA-is-awesome/GENOMES/CNA3-gobs_fixed.fa", "/Users/jordanburke/RNA-is-awesome/GENOMES/CNA3_FINAL_CALLGENES_1_gobs.gff3", "CM764-A_5p_All_indexes.txt")

# %%
cd PEAKPICKING/
# Out:
# [Errno 2] No such file or directory: 'PEAKPICKING/'
# /Users/jordanburke/RNA-is-awesome/SP_ANALYSIS/PEAKPICKING

# %%
SPTools.peaks_by_gene("/Users/jordanburke/RNA-is-awesome/GENOMES/CNA3_FINAL_CALLGENES_1_gobs.gff3", "/Users/jordanburke/Documents/JEB/HTSeq/JEB002/150904BAMFILES/CM764-A_5p.bedGraph")
# Out:
# 7813
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-7726a854107c> in <module>()
# ----> 1 SPTools.peaks_by_gene("/Users/jordanburke/RNA-is-awesome/GENOMES/CNA3_FINAL_CALLGENES_1_gobs.gff3", "/Users/jordanburke/Documents/JEB/HTSeq/JEB002/150904BAMFILES/CM764-A_5p.bedGraph")
#
# /Users/jordanburke/RNA-is-awesome/SP_analysis/SPTools/SPPeaks.py in peaks_by_gene(gff3_file, bedgraph_file, chromosome, gene_list)
#     117             for CNAG, coords in transcript_dict.iteritems():
#     118                 #Empty dictionary for bedgraph. Values will be [list of genomic positions][reads starting at that position]
# --> 119                 if int(columns[1]) > coords[0] and int(columns[1]) < coords[1]:
#     120                     bedgraph_dict[CNAG][0].append(int(columns[1]))
#     121                     bedgraph_dict[CNAG][1].append(int(columns[3]))
#
# ...

# %%
cd ../
# Out:
# /Users/jordanburke/RNA-is-awesome

# %%
run get_CNAG.py --transcript="CNAG_01733T0" --flanks
# Out:
# {'--flanks': True,
#  '--transcript': 'CNAG_01733T0',
#  '--transcript_file': None}
# ['CNAG_01733T0']
# True
